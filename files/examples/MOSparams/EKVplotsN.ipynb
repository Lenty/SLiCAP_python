# %%
from SLiCAP import *
t1 = time()
# Out:
# /home/anton/.local/lib/python3.8/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.25.10) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# Succesfully self-tested the Maxima command.
# SLiCAP Version matches with the latest release of SLiCAP on github.
# Running from an Ipython enviroment, importing SLiCAPnotebook.

# %%
# Define a project
prj = initProject('NMOS EKV plots') # Creates the SLiCAP libraries and the
                                    # project HTML index page

# %%
fileName = 'mosEKVplotsN_V.cir'
i1 = instruction()           # Creates an instance of an instruction object
i1.setCircuit(fileName)      # Checks and defines the local circuit object and
                             # sets the index page to the circuit index page
# Out:
# No errors found for circuit: 'mosEKVplots' from file: 'mosEKVplotsN_V.cir'.

# %%
htmlPage('Circuit data')
HTML(netlist2html(fileName))
# Out:
# <h2>Netlist: mosEKVplotsN_V.cir</h2>
# <pre>mosEKVplots
# * SLiCAP netlist file
# .include SLiCAP.lib
# X1 d g s 0 CMOS18N_V W={W} L={L} VD={V_D} VG={V_G} VS={V_S}
# .param V_D=1.8 V_G=0.5 V_S=0 W=220n L=180n
# .end
# </pre>

# %%
# Print data of elements of expanded network
HTML(elementData2html(i1.circuit))
# Out:
# <table><caption>Table: Element data of expanded netlist 'mosEKVplots'</caption>
# <tr><th class="left">RefDes</th><th class="left">Nodes</th><th class="left">Refs</th><th class="left">Model</th><th class="left">Param</th><th class="left">Symbolic</th><th class="left">Numeric</th></tr>
# <tr><td class="left">Cdb_M1_X1</td><td class = "left">d 0 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$c_{db X1}$$</td><td class="left">$$3.96 \cdot 10^{-17}$$</td></tr>
# <tr><td class="left">Cdg_M1_X1</td><td class = "left">d g </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$c_{dg X1}$$</td><td class="left">$$6.6 \cdot 10^{-17}$$</td></tr>
# <tr><td class="left">Cgb_M1_X1</td><td class = "left">g 0 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$c_{gb X1}$$</td><td class="left">$$4.388 \cdot 10^{-17}$$</td></tr>
# <tr><td class="left">Cgs_M1_X1</td><td class = "left">g s </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$c_{gs X1}$$</td><td class="left">$$2.316 \cdot 10^{-16}$$</td></tr>
# <tr><td class="left">Csb_M1_X1</td><td class = "left">s 0 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$c_{sb X1}$$</td><td class="left">$$9.758 \cdot 10^{-17}$$</td></tr>
# <tr><td class="left">Gb_M1_X1</td><td class = "left">d s 0 s </td><td class = "left"></td><td class = "left">g</td>
# <td class="left">value</td><td class="left">$$g_{b X1}$$</td><td class="left">$$1.649 \cdot 10^{-5}$$</td></tr>
# <tr><td class="left">Gm_M1_X1</td><td class = "left">d s g s </td><td class = "left"></td><td class = "left">g</td>
# <td class="left">value</td><td class="left">$$g_{m X1}$$</td><td class="left">$$4.711 \cdot 10^{-5}$$</td></tr>
# <tr><td class="left">Go_M1_X1</td><td class = "left">d s d s </td><td class = "left"></td><td class = "left">g</td>
# <td class="left">value</td><td class="left">$$g_{o X1}$$</td><td class="left">$$4.34 \cdot 10^{-7}$$</td></tr>
# </table>

# %%
# Print the circuit parameters
HTML(params2html(i1.circuit))
# Out:
# <table><caption>Table: Parameter definitions in 'mosEKVplots'.</caption>
# <tr><th class="left">Name</th><th class="left">Symbolic</th><th class="left">Numeric</th></tr>
# <tr><td class="left">$$CGBO_{N18}$$</td><td class="left">$$1.0 \cdot 10^{-12}$$</td><td class="left">$$1.0 \cdot 10^{-12}$$</td></tr>
# <tr><td class="left">$$CGSO_{N18}$$</td><td class="left">$$3.0 \cdot 10^{-10}$$</td><td class="left">$$3.0 \cdot 10^{-10}$$</td></tr>
# <tr><td class="left">$$CJB_{0 N18}$$</td><td class="left">$$0.001$$</td><td class="left">$$0.001$$</td></tr>
# <tr><td class="left">$$C_{OX N18}$$</td><td class="left">$$\frac{\epsilon_{0} \epsilon_{SiO2}}{TOX_{N18}}$$</td><td class="left">$$0.008422$$</td></tr>
# <tr><td class="left">$$E_{CRIT N18}$$</td><td class="left">$$5.6 \cdot 10^{6}$$</td><td class="left">$$5.6 \cdot 10^{6}$$</td></tr>
# <tr><td class="left">$$I_{0 N18}$$</td><td class="left">$$2 C_{OX N18} N_{s N18} U_{T}^{2} u_{0 N18}$$</td><td class="left">$$6.413 \cdot 10^{-7}$$</td></tr>
# <tr><td class="left">$$L$$</td><td class="left">$$1.8 \cdot 10^{-7}$$</td><td class="left">$$1.8 \cdot 10^{-7}$$</td></tr>
# <tr><td class="left">$$LDS_{N18}$$</td><td class="left">$$1.8 \cdot 10^{-7}$$</td><td class="left">$$1.8 \cdot 10^{-7}$$</td></tr>
# <tr><td class="left">$$N_{s N18}$$</td><td class="left">$$1.35$$</td><td class="left">$$1.35$$</td></tr>
# <tr><td class="left">$$T$$</td><td class="left">$$300$$</td><td class="left">$$300.0$$</td></tr>
# <tr><td class="left">$$TOX_{N18}$$</td><td class="left">$$4.1 \cdot 10^{-9}$$</td><td class="left">$$4.1 \cdot 10^{-9}$$</td></tr>
# <tr><td class="left">$$\Theta_{N18}$$</td><td class="left">$$0.28$$</td><td class="left">$$0.28$$</td></tr>
# <tr><td class="left">$$U_{T}$$</td><td class="left">$$\frac{T k}{q}$$</td><td class="left">$$0.02585$$</td></tr>
# <tr><td class="left">$$VAL_{N18}$$</td><td class="left">$$4.0 \cdot 10^{7}$$</td><td class="left">$$4.0 \cdot 10^{7}$$</td></tr>
# <tr><td class="left">$$V_{D}$$</td><td class="left">$$1.8$$</td><td class="left">$$1.8$$</td></tr>
# <tr><td class="left">$$V_{G}$$</td><td class="left">$$0.5$$</td><td class="left">$$0.5$$</td></tr>
# <tr><td class="left">$$V_{S}$$</td><td class="left">$$0$$</td><td class="left">$$0$$</td></tr>
# <tr><td class="left">$$Vth_{N18}$$</td><td class="left">$$0.36$$</td><td class="left">$$0.36$$</td></tr>
# <tr><td class="left">$$W$$</td><td class="left">$$2.2 \cdot 10^{-7}$$</td><td class="left">$$2.2 \cdot 10^{-7}$$</td></tr>
# <tr><td class="left">$$c$$</td><td class="left">$$2.998 \cdot 10^{8}$$</td><td class="left">$$2.998 \cdot 10^{8}$$</td></tr>
# <tr><td class="left">$$\epsilon_{0}$$</td><td class="left">$$\frac{1}{c^{2} \mu_{0}}$$</td><td class="left">$$8.854 \cdot 10^{-12}$$</td></tr>
# <tr><td class="left">$$\epsilon_{SiO2}$$</td><td class="left">$$3.9$$</td><td class="left">$$3.9$$</td></tr>
# <tr><td class="left">$$k$$</td><td class="left">$$1.381 \cdot 10^{-23}$$</td><td class="left">$$1.381 \cdot 10^{-23}$$</td></tr>
# <tr><td class="left">$$\mu_{0}$$</td><td class="left">$$4.0 \cdot 10^{-7} \pi$$</td><td class="left">$$1.257 \cdot 10^{-6}$$</td></tr>
# <tr><td class="left">$$q$$</td><td class="left">$$1.602 \cdot 10^{-19}$$</td><td class="left">$$1.602 \cdot 10^{-19}$$</td></tr>
# <tr><td class="left">$$u_{0 N18}$$</td><td class="left">$$0.0422$$</td><td class="left">$$0.0422$$</td></tr>
# <tr><td class="left">$$C_{db0 X1}$$</td><td class="left">$$CJB_{0 N18} LDS_{N18} W$$</td><td class="left">$$3.96 \cdot 10^{-17}$$</td></tr>
# <tr><td class="left">$$C_{gbo X1}$$</td><td class="left">$$2 CGBO_{N18} L$$</td><td class="left">$$3.6 \cdot 10^{-19}$$</td></tr>
# <tr><td class="left">$$C_{gdo X1}$$</td><td class="left">$$CGSO_{N18} W$$</td><td class="left">$$6.6 \cdot 10^{-17}$$</td></tr>
# <tr><td class="left">$$C_{gso X1}$$</td><td class="left">$$CGSO_{N18} W$$</td><td class="left">$$6.6 \cdot 10^{-17}$$</td></tr>
# <tr><td class="left">$$C_{sb0 X1}$$</td><td class="left">$$CJB_{0 N18} LDS_{N18} W$$</td><td class="left">$$3.96 \cdot 10^{-17}$$</td></tr>
# <tr><td class="left">$$IC_{CRIT X1}$$</td><td class="left">$$\frac{1}{16 N_{s N18}^{2} U_{T}^{2} \left(\Theta_{N18} + \frac{1}{E_{CRIT N18} L}\right)^{2}}$$</td><td class="left">$$31.71$$</td></tr>
# <tr><td class="left">$$IC_{F X1}$$</td><td class="left">$$\log{\left(e^{\frac{V_{effF X1}}{2}} + 1 \right)}^{2}$$</td><td class="left">$$4.545$$</td></tr>
# <tr><td class="left">$$IC_{R X1}$$</td><td class="left">$$\log{\left(e^{\frac{V_{effR X1}}{2}} + 1 \right)}^{2}$$</td><td class="left">$$3.081 \cdot 10^{-29}$$</td></tr>
# <tr><td class="left">$$I_{DS X1}$$</td><td class="left">$$\frac{I_{0 N18} W \left(1 + \frac{V_{D} - V_{S}}{V_{A X1}}\right) \left(IC_{F X1} - IC_{R X1}\right)}{L \left(U_{T} \sqrt{IC_{F X1} + IC_{R X1}} \left(2 \Theta_{N18} + \frac{2}{E_{CRIT N18} L}\right) + 1\right)}$$</td><td class="left">$$3.906 \cdot 10^{-6}$$</td></tr>
# <tr><td class="left">$$V_{A X1}$$</td><td class="left">$$L VAL_{N18}$$</td><td class="left">$$7.2$$</td></tr>
# <tr><td class="left">$$V_{effF X1}$$</td><td class="left">$$\frac{- N_{s N18} V_{S} + V_{G} - Vth_{N18}}{N_{s N18} U_{T}}$$</td><td class="left">$$4.011$$</td></tr>
# <tr><td class="left">$$V_{effR X1}$$</td><td class="left">$$\frac{- N_{s N18} V_{D} + V_{G} - Vth_{N18}}{N_{s N18} U_{T}}$$</td><td class="left">$$-65.62$$</td></tr>
# <tr><td class="left">$$c_{db X1}$$</td><td class="left">$$C_{db0 X1} + c_{dgi X1} \left(N_{s N18} - 1\right)$$</td><td class="left">$$3.96 \cdot 10^{-17}$$</td></tr>
# <tr><td class="left">$$c_{dg X1}$$</td><td class="left">$$C_{gdo X1} + c_{dgi X1}$$</td><td class="left">$$6.6 \cdot 10^{-17}$$</td></tr>
# <tr><td class="left">$$c_{dgi X1}$$</td><td class="left">$$C_{OX N18} L W \left(\frac{2}{3} - \frac{2 \left(x_{f X1}^{2} + x_{f X1} + 0.5 x_{r X1}\right)}{3 \left(x_{f X1} + x_{r X1}\right)^{2}}\right)$$</td><td class="left">$$0$$</td></tr>
# <tr><td class="left">$$c_{gb X1}$$</td><td class="left">$$C_{gbo X1} + \frac{\left(N_{s N18} - 1\right) \left(C_{OX N18} L W - c_{dgi X1} - c_{gsi X1}\right)}{N_{s N18}}$$</td><td class="left">$$4.388 \cdot 10^{-17}$$</td></tr>
# <tr><td class="left">$$c_{gs X1}$$</td><td class="left">$$C_{gso X1} + c_{gsi X1}$$</td><td class="left">$$2.316 \cdot 10^{-16}$$</td></tr>
# <tr><td class="left">$$c_{gsi X1}$$</td><td class="left">$$C_{OX N18} L W \left(\frac{2}{3} - \frac{2 \left(0.5 x_{f X1} + x_{r X1}^{2} + x_{r X1}\right)}{3 \left(x_{f X1} + x_{r X1}\right)^{2}}\right)$$</td><td class="left">$$1.657 \cdot 10^{-16}$$</td></tr>
# <tr><td class="left">$$c_{iss X1}$$</td><td class="left">$$c_{dg X1} + c_{gb X1} + c_{gs X1}$$</td><td class="left">$$3.415 \cdot 10^{-16}$$</td></tr>
# <tr><td class="left">$$c_{sb X1}$$</td><td class="left">$$C_{sb0 X1} + c_{gsi X1} \left(N_{s N18} - 1\right)$$</td><td class="left">$$9.758 \cdot 10^{-17}$$</td></tr>
# <tr><td class="left">$$f_{T X1}$$</td><td class="left">$$\frac{g_{m X1}}{2 \pi c_{iss X1}}$$</td><td class="left">$$2.195 \cdot 10^{10}$$</td></tr>
# <tr><td class="left">$$g_{b X1}$$</td><td class="left">$$g_{m X1} \left(N_{s N18} - 1\right)$$</td><td class="left">$$1.649 \cdot 10^{-5}$$</td></tr>
# <tr><td class="left">$$g_{mF X1}$$</td><td class="left">$$\frac{IC_{F X1} I_{0 N18} W \left(1 + \frac{V_{D} - V_{S}}{V_{A X1}}\right)}{L N_{s N18} U_{T} \sqrt{IC_{F X1} \left(1 + \frac{IC_{F X1}}{IC_{CRIT X1}}\right) + 0.5 \sqrt{IC_{F X1} \left(1 + \frac{IC_{F X1}}{IC_{CRIT X1}}\right)} + 1}}$$</td><td class="left">$$4.711 \cdot 10^{-5}$$</td></tr>
# <tr><td class="left">$$g_{mR X1}$$</td><td class="left">$$\frac{IC_{R X1} I_{0 N18} W \left(1 + \frac{- V_{D} + V_{S}}{V_{A X1}}\right)}{L N_{s N18} U_{T} \sqrt{IC_{R X1} \left(1 + \frac{IC_{R X1}}{IC_{CRIT X1}}\right) + 0.5 \sqrt{IC_{R X1} \left(1 + \frac{IC_{R X1}}{IC_{CRIT X1}}\right)} + 1}}$$</td><td class="left">$$5.191 \cdot 10^{-34}$$</td></tr>
# <tr><td class="left">$$g_{m X1}$$</td><td class="left">$$g_{mF X1} - g_{mR X1}$$</td><td class="left">$$4.711 \cdot 10^{-5}$$</td></tr>
# <tr><td class="left">$$g_{o X1}$$</td><td class="left">$$\frac{2 C_{OX N18} \sqrt{IC_{R X

# %%
# Create an HTML page for the plots
htmlPage('CMOS18 EKV model plots')
# Create the plot: set the data type to 'params' and define the step variable. 
# The x variable, the y variable and the sweep variable will be defined with the plot.
# We will start with plotting I_DS versus V_DS with V_GS as step parameter and V_DS as sweep parameter.
i1.setDataType('params')
i1.setStepVar('V_G')
i1.setStepStart(0.001)
i1.setStepStop(1.8)
i1.setStepNum(10)
i1.setStepMethod('lin')
i1.stepOn()
result = i1.execute()

# %%
fig_Ids_Vds = plotSweep('IdsVds', '$I_{ds}(V_{ds})$', result, 0, 1.8, 50, sweepVar= 'V_D', xUnits = 'V', yVar = 'I_DS_X1', yScale = 'u', yUnits = 'A', funcType = 'param', show = True)
fig2html(fig_Ids_Vds, 600)
# Out:
# '/home/anton/SLiCAP/examples/MOSparams/html/img/IdsVds.svg'

# %%
# All other plots will be made with V_GS as sweep parameter and V_DS as step parameter.
i1.setStepVar('V_D')
result = i1.execute()

# %%
fig_Ids_Vgs = plotSweep('IdsVgs', '$I_{ds}(V_{gs})$', result, 0, 1.8, 50, sweepVar= 'V_G', xUnits = 'V', yVar = 'I_DS_X1', yScale = 'u', yUnits = 'A', funcType = 'param', show = True)
fig2html(fig_Ids_Vgs, 600)
# Out:
# '/home/anton/SLiCAP/examples/MOSparams/html/img/IdsVgs.svg'

# %%
fig_gm_Ids = plotSweep('gmIds', '$g_m(I_{ds})$', result, 0, 1.8, 50, sweepVar= 'V_G', xVar = 'I_DS_X1', xScale = 'u', xUnits = 'A', yVar = 'g_m_X1', yScale = 'u', yUnits = 'S', funcType = 'param', show = True)
fig2html(fig_gm_Ids, 600)
# Out:
# '/home/anton/SLiCAP/examples/MOSparams/html/img/gmIds.svg'

# %%
fig_fT_Ids = plotSweep('fTIds', '$f_{T}(I_{ds})$', result, 0, 1.8, 50, sweepVar= 'V_G', xVar = 'I_DS_X1', xScale = 'u', xUnits = 'A', yVar = 'f_T_X1', yScale = 'G', yUnits = 'Hz', funcType = 'param', show = True)
fig2html(fig_fT_Ids, 600)
# Out:
# '/home/anton/SLiCAP/examples/MOSparams/html/img/fTIds.svg'

# %%
fig_CissVg = plotSweep('CissVg', '$c_{iss}(V_{gs})$', result, 0, 1.8, 50, sweepVar= 'V_G', xScale = '', xUnits = 'V', yVar = 'c_iss_X1', yScale = 'f', yUnits = 'F', funcType = 'param', show = True)
fig2html(fig_CissVg, 600)
# Out:
# '/home/anton/SLiCAP/examples/MOSparams/html/img/CissVg.svg'

# %%
t2=time()
print(t2-t1,'s')
# Out:
# 6.587650299072266 s
