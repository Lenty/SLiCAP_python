# %%
from SLiCAPnotebook import *
# Always run SLiCAP from the project directory, this will use the correct path settings.
t1=time()

# %%
prj = initProject('My first SLiCAP project') # Sets all the paths and creates the HTML main index page.

fileName = 'PIVA.cir'
i1 = instruction()                           # Creates an instance of an instruction object
i1.setCircuit(fileName)                      # Checks and defines the local circuit object and
                                             # sets the index page to the circuit index page

i1.defPar('C_ph', '2.95p')                   # Correct value for frequency compenmsation

# Generate HTML report.                          
htmlPage('Circuit data')                     # Creates an HTML page and a link on the index page of this circuit
# Out:
# No errors found for circuit: 'PIVA' from file: 'PIVA.cir'.

# %%
SVG(filename=img2html('PIVA.svg', 800))

# %%
HTML(netlist2html(fileName, label = 'netlist'))
# Out:
# <h2><a id="netlist"></a>Netlist: PIVA.cir</h2>
# <pre>"PIVA"
# * gnetlist -q -g spice-noqsi -o PIVA.net PIVA.sch
# * SPICE file generated by spice-noqsi version 20170819
# * Send requests or bug reports to jpd@noqsi.com
# V1 8 0 V value=1 dc=0 dcvar=0 noise=0
# R9 9 13 {R_d}
# R8 6 0 {R_a}
# R7 9 Out {R_m}
# R6 10 6 {R_b}
# R5 2 3 {R_led}
# R4 5 0 {R_se}
# R3 7 9 {R_f}
# R2 4 1 {R_vi}
# R1 8 7 {R_i}
# O3 0 10 11 0 AD8610
# O2 0 1 5 2 AD8610
# O1 0 7 4 0 AD8610
# M1 9 11 6 6 NDD03N80Z
# F2 1 0 12 0 5m
# F1 0 10 3 12 5m
# C_9 13 0 {C_d}
# C8 Out 0 {C_p}
# C7 10 6 {C_c}
# C6 10 0 {C_pin}
# C5 2 0 {C_led}
# C4 1 0 {2*C_pin}
# C3 1 5 {C_f}
# C2 7 9 {C_ph}
# C1 7 4 {C_i}
# .param R_i=80.6k C_i=10p C_ph=1.95p R_f=2M C_pin=22p R_vi=51k C_f=4.7p C_led=80p R_led=25 R_se=300 C_c=3.9p R_b=51k R_a=510 R_m=150 C_d=220p R_d=1k C_p=1n I_D=1m
# .end
# </pre>

# %%
HTML(elementData2html(i1.circuit, label = 'elementData'))
# Out:
# <a id="elementData"></a><table><caption>Table: Element data of expanded netlist 'PIVA'</caption>
# <tr><th class="left">RefDes</th><th class="left">Nodes</th><th class="left">Refs</th><th class="left">Model</th><th class="left">Param</th><th class="left">Symbolic</th><th class="left">Numeric</th></tr>
# <tr><td class="left">C1</td><td class = "left">7 4 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$C_{i}$$</td><td class="left">$$1.0 \cdot 10^{-11}$$</td></tr>
# <tr><td class="left">C2</td><td class = "left">7 9 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$C_{ph}$$</td><td class="left">$$2.95 \cdot 10^{-12}$$</td></tr>
# <tr><td class="left">C3</td><td class = "left">1 5 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$C_{f}$$</td><td class="left">$$4.7 \cdot 10^{-12}$$</td></tr>
# <tr><td class="left">C4</td><td class = "left">1 0 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$2 C_{pin}$$</td><td class="left">$$4.4 \cdot 10^{-11}$$</td></tr>
# <tr><td class="left">C5</td><td class = "left">2 0 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$C_{led}$$</td><td class="left">$$8.0 \cdot 10^{-11}$$</td></tr>
# <tr><td class="left">C6</td><td class = "left">10 0 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$C_{pin}$$</td><td class="left">$$2.2 \cdot 10^{-11}$$</td></tr>
# <tr><td class="left">C7</td><td class = "left">10 6 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$C_{c}$$</td><td class="left">$$3.9 \cdot 10^{-12}$$</td></tr>
# <tr><td class="left">C8</td><td class = "left">Out 0 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$C_{p}$$</td><td class="left">$$1.0 \cdot 10^{-9}$$</td></tr>
# <tr><td class="left">C_9</td><td class = "left">13 0 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$C_{d}$$</td><td class="left">$$2.2 \cdot 10^{-10}$$</td></tr>
# <tr><td class="left">Cc1_O1</td><td class = "left">0 0 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$4.0 \cdot 10^{-12}$$</td><td class="left">$$4.0 \cdot 10^{-12}$$</td></tr>
# <tr><td class="left">Cc1_O2</td><td class = "left">0 2 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$4.0 \cdot 10^{-12}$$</td><td class="left">$$4.0 \cdot 10^{-12}$$</td></tr>
# <tr><td class="left">Cc1_O3</td><td class = "left">0 0 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$4.0 \cdot 10^{-12}$$</td><td class="left">$$4.0 \cdot 10^{-12}$$</td></tr>
# <tr><td class="left">Cc2_O1</td><td class = "left">7 0 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$4.0 \cdot 10^{-12}$$</td><td class="left">$$4.0 \cdot 10^{-12}$$</td></tr>
# <tr><td class="left">Cc2_O2</td><td class = "left">1 2 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$4.0 \cdot 10^{-12}$$</td><td class="left">$$4.0 \cdot 10^{-12}$$</td></tr>
# <tr><td class="left">Cc2_O3</td><td class = "left">10 0 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$4.0 \cdot 10^{-12}$$</td><td class="left">$$4.0 \cdot 10^{-12}$$</td></tr>
# <tr><td class="left">Cd_O1</td><td class = "left">0 7 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$1.5 \cdot 10^{-11}$$</td><td class="left">$$1.5 \cdot 10^{-11}$$</td></tr>
# <tr><td class="left">Cd_O2</td><td class = "left">0 1 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$1.5 \cdot 10^{-11}$$</td><td class="left">$$1.5 \cdot 10^{-11}$$</td></tr>
# <tr><td class="left">Cd_O3</td><td class = "left">0 10 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$1.5 \cdot 10^{-11}$$</td><td class="left">$$1.5 \cdot 10^{-11}$$</td></tr>
# <tr><td class="left">Cdb_M1</td><td class = "left">9 6 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$4.0 \cdot 10^{-11}$$</td><td class="left">$$4.0 \cdot 10^{-11}$$</td></tr>
# <tr><td class="left">Cdg_M1</td><td class = "left">9 11 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$8.0 \cdot 10^{-12}$$</td><td class="left">$$8.0 \cdot 10^{-12}$$</td></tr>
# <tr><td class="left">Cgb_M1</td><td class = "left">11 6 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$0$$</td><td class="left">$$0$$</td></tr>
# <tr><td class="left">Cgs_M1</td><td class = "left">11 6 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$4.0 \cdot 10^{-10}$$</td><td class="left">$$4.0 \cdot 10^{-10}$$</td></tr>
# <tr><td class="left">Csb_M1</td><td class = "left">6 6 </td><td class = "left"></td><td class = "left">C</td>
# <td class="left">value</td><td class="left">$$0$$</td><td class="left">$$0$$</td></tr>
# <tr><td class="left">E_O1</td><td class = "left">4 0 0 7 </td><td class = "left"></td><td class = "left">EZ</td>
# <td class="left">value</td><td class="left">$$\frac{- \frac{0.00125 s}{\pi} + 3.0 \cdot 10^{5}}{\left(\frac{4.167 \cdot 10^{-9} s}{\pi} + 1\right) \left(\frac{0.0075 s}{\pi} + 1\right)}$$</td><td class="left">$$\frac{3.0 \cdot 10^{5} - 0.0003979 s}{\left(1.326 \cdot 10^{-9} s + 1\right) \left(0.002387 s + 1\right)}$$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">zo</td><td class="left">$$20$$</td><td class="left">$$20.0$$</td></tr>
# <tr><td class="left">E_O2</td><td class = "left">5 2 0 1 </td><td class = "left"></td><td class = "left">EZ</td>
# <td class="left">value</td><td class="left">$$\frac{- \frac{0.00125 s}{\pi} + 3.0 \cdot 10^{5}}{\left(\frac{4.167 \cdot 10^{-9} s}{\pi} + 1\right) \left(\frac{0.0075 s}{\pi} + 1\right)}$$</td><td class="left">$$\frac{3.0 \cdot 10^{5} - 0.0003979 s}{\left(1.326 \cdot 10^{-9} s + 1\right) \left(0.002387 s + 1\right)}$$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">zo</td><td class="left">$$20$$</td><td class="left">$$20.0$$</td></tr>
# <tr><td class="left">E_O3</td><td class = "left">11 0 0 10 </td><td class = "left"></td><td class = "left">EZ</td>
# <td class="left">value</td><td class="left">$$\frac{- \frac{0.00125 s}{\pi} + 3.0 \cdot 10^{5}}{\left(\frac{4.167 \cdot 10^{-9} s}{\pi} + 1\right) \left(\frac{0.0075 s}{\pi} + 1\right)}$$</td><td class="left">$$\frac{3.0 \cdot 10^{5} - 0.0003979 s}{\left(1.326 \cdot 10^{-9} s + 1\right) \left(0.002387 s + 1\right)}$$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">zo</td><td class="left">$$20$$</td><td class="left">$$20.0$$</td></tr>
# <tr><td class="left">F1</td><td class = "left">0 10 3 12 </td><td class = "left"></td><td class = "left">F</td>
# <td class="left">value</td><td class="left">$$0.005$$</td><td class="left">$$0.005$$</td></tr>
# <tr><td class="left">F2</td><td class = "left">1 0 12 0 </td><td class = "left"></td><td class = "left">F</td>
# <td class="left">value</td><td class="left">$$0.005$$</td><td class="left">$$0.005$$</td></tr>
# <tr><td class="left">Gb_M1</td><td class = "left">9 6 6 6 </td><td class = "left"></td><td class = "left">g</td>
# <td class="left">value</td><td class="left">$$0$$</td><td class="left">$$0$$</td></tr>
# <tr><td class="left">Gc1_O1</td><td class = "left">0 0 0 0 </td><td class = "left"></td><td class = "left">g</td>
# <td class="left">value</td><td class="left">$$0$$</td><td class="left">$$0$$</td></tr>
# <tr><td class="left">Gc1_O2</td><td class = "left">0 2 0 2 </td>

# %%
HTML(params2html(i1.circuit, label = 'params'))
# Out:
# <a id="params"></a><table><caption>Table: Parameter definitions in 'PIVA'.</caption>
# <tr><th class="left">Name</th><th class="left">Symbolic</th><th class="left">Numeric</th></tr>
# <tr><td class="left">$$C_{c}$$</td><td class="left">$$3.9 \cdot 10^{-12}$$</td><td class="left">$$3.9 \cdot 10^{-12}$$</td></tr>
# <tr><td class="left">$$C_{d}$$</td><td class="left">$$2.2 \cdot 10^{-10}$$</td><td class="left">$$2.2 \cdot 10^{-10}$$</td></tr>
# <tr><td class="left">$$C_{f}$$</td><td class="left">$$4.7 \cdot 10^{-12}$$</td><td class="left">$$4.7 \cdot 10^{-12}$$</td></tr>
# <tr><td class="left">$$C_{i}$$</td><td class="left">$$1.0 \cdot 10^{-11}$$</td><td class="left">$$1.0 \cdot 10^{-11}$$</td></tr>
# <tr><td class="left">$$C_{led}$$</td><td class="left">$$8.0 \cdot 10^{-11}$$</td><td class="left">$$8.0 \cdot 10^{-11}$$</td></tr>
# <tr><td class="left">$$C_{p}$$</td><td class="left">$$1.0 \cdot 10^{-9}$$</td><td class="left">$$1.0 \cdot 10^{-9}$$</td></tr>
# <tr><td class="left">$$C_{ph}$$</td><td class="left">$$2.95 \cdot 10^{-12}$$</td><td class="left">$$2.95 \cdot 10^{-12}$$</td></tr>
# <tr><td class="left">$$C_{pin}$$</td><td class="left">$$2.2 \cdot 10^{-11}$$</td><td class="left">$$2.2 \cdot 10^{-11}$$</td></tr>
# <tr><td class="left">$$I_{D}$$</td><td class="left">$$0.001$$</td><td class="left">$$0.001$$</td></tr>
# <tr><td class="left">$$R_{a}$$</td><td class="left">$$510$$</td><td class="left">$$510.0$$</td></tr>
# <tr><td class="left">$$R_{b}$$</td><td class="left">$$5.1 \cdot 10^{4}$$</td><td class="left">$$5.1 \cdot 10^{4}$$</td></tr>
# <tr><td class="left">$$R_{d}$$</td><td class="left">$$1000.0$$</td><td class="left">$$1000.0$$</td></tr>
# <tr><td class="left">$$R_{f}$$</td><td class="left">$$2.0 \cdot 10^{6}$$</td><td class="left">$$2.0 \cdot 10^{6}$$</td></tr>
# <tr><td class="left">$$R_{i}$$</td><td class="left">$$8.06 \cdot 10^{4}$$</td><td class="left">$$8.06 \cdot 10^{4}$$</td></tr>
# <tr><td class="left">$$R_{led}$$</td><td class="left">$$25$$</td><td class="left">$$25.0$$</td></tr>
# <tr><td class="left">$$R_{m}$$</td><td class="left">$$150$$</td><td class="left">$$150.0$$</td></tr>
# <tr><td class="left">$$R_{se}$$</td><td class="left">$$300$$</td><td class="left">$$300.0$$</td></tr>
# <tr><td class="left">$$R_{vi}$$</td><td class="left">$$5.1 \cdot 10^{4}$$</td><td class="left">$$5.1 \cdot 10^{4}$$</td></tr>
# </table>

# %%
i1.setGainType ('vi')
i1.setSimType('symbolic')
i1.setDataType('matrix')
i1.setSource('V1')
i1.setDetector(['V_Out', 'V_0'])
matrixResult = i1.execute()

# %%
htmlPage('Symbolic matrix representation')

# %%
HTML(matrices2html(matrixResult));

# %%
htmlPage('Poles and zeros')

# %%
i1.setSimType('numeric')
i1.setGainType('gain')
i1.setLGref('F1')
i1.setDataType('poles')
polesResult = i1.execute()
HTML(pz2html(polesResult, label = 'tab_poles'))
# Out:
# <h2><a id="tab_poles"></a>Poles  analysis results</h2>
# <h3>Gain type: gain</h3><table><tr><th>pole</th><th>Re [Hz]</th><th>Im [Hz]</th><th>Mag [Hz]</th><th>Q</th></tr>
# <tr><td>p<sub>1</sub></td><td>-4.235e+4</td><td>-2.544e+4</td><td>4.940e+4</td><td>0.5833</td></tr>
# <tr><td>p<sub>2</sub></td><td>-4.235e+4</td><td>2.544e+4</td><td>4.940e+4</td><td>0.5833</td></tr>
# <tr><td>p<sub>3</sub></td><td>-4.997e+5</td><td>-5.114e+5</td><td>7.150e+5</td><td>0.7154</td></tr>
# <tr><td>p<sub>4</sub></td><td>-4.997e+5</td><td>5.114e+5</td><td>7.150e+5</td><td>0.7154</td></tr>
# <tr><td>p<sub>5</sub></td><td>-7.742e+5</td><td></td><td>7.742e+5</td><td></td></tr>
# <tr><td>p<sub>6</sub></td><td>-9.328e+5</td><td>-8.238e+5</td><td>1.245e+6</td><td>0.6671</td></tr>
# <tr><td>p<sub>7</sub></td><td>-9.328e+5</td><td>8.238e+5</td><td>1.245e+6</td><td>0.6671</td></tr>
# <tr><td>p<sub>8</sub></td><td>-7.149e+6</td><td></td><td>7.149e+6</td><td></td></tr>
# <tr><td>p<sub>9</sub></td><td>-1.465e+7</td><td>-1.680e+7</td><td>2.229e+7</td><td>0.7610</td></tr>
# <tr><td>p<sub>10</sub></td><td>-1.465e+7</td><td>1.680e+7</td><td>2.229e+7</td><td>0.7610</td></tr>
# <tr><td>p<sub>11</sub></td><td>-7.568e+7</td><td></td><td>7.568e+7</td><td></td></tr>
# <tr><td>p<sub>12</sub></td><td>-1.053e+8</td><td></td><td>1.053e+8</td><td></td></tr>
# <tr><td>p<sub>13</sub></td><td>-1.168e+8</td><td></td><td>1.168e+8</td><td></td></tr>
# <tr><td>p<sub>14</sub></td><td>-1.171e+8</td><td></td><td>1.171e+8</td><td></td></tr>
# <tr><td>p<sub>15</sub></td><td>-1.115e+9</td><td></td><td>1.115e+9</td><td></td></tr>
# <tr><td>p<sub>16</sub></td><td>-1.660e+9</td><td></td><td>1.660e+9</td><td></td></tr>
# <tr><td>p<sub>17</sub></td><td>-2.019e+9</td><td></td><td>2.019e+9</td><td></td></tr>
# </table>

# %%
i1.setDataType('zeros')
zerosResult = i1.execute()
HTML(pz2html(zerosResult, label = 'tab_zeros'))
# Out:
# <h2><a id="tab_zeros"></a>Zeros  analysis results</h2>
# <h3>Gain type: gain</h3><table><tr><th>zero</th><th>Re [Hz]</th><th>Im [Hz]</th><th>Mag [Hz]</th><th>Q</th></tr>
# <tr><td>z<sub>1</sub></td><td>-7.234e+5</td><td></td><td>7.234e+5</td><td></td></tr>
# <tr><td>z<sub>2</sub></td><td>2.833e+6</td><td></td><td>2.833e+6</td><td></td></tr>
# <tr><td>z<sub>3</sub></td><td>1.419e+6</td><td>-2.916e+6</td><td>3.243e+6</td><td>1.143</td></tr>
# <tr><td>z<sub>4</sub></td><td>1.419e+6</td><td>2.916e+6</td><td>3.243e+6</td><td>1.143</td></tr>
# <tr><td>z<sub>5</sub></td><td>-2.171e+6</td><td>-3.373e+6</td><td>4.011e+6</td><td>0.9240</td></tr>
# <tr><td>z<sub>6</sub></td><td>-2.171e+6</td><td>3.373e+6</td><td>4.011e+6</td><td>0.9240</td></tr>
# <tr><td>z<sub>7</sub></td><td>-4.311e+6</td><td></td><td>4.311e+6</td><td></td></tr>
# <tr><td>z<sub>8</sub></td><td>-2.470e+7</td><td></td><td>2.470e+7</td><td></td></tr>
# <tr><td>z<sub>9</sub></td><td>-7.568e+7</td><td></td><td>7.568e+7</td><td></td></tr>
# <tr><td>z<sub>10</sub></td><td>-1.079e+8</td><td></td><td>1.079e+8</td><td></td></tr>
# <tr><td>z<sub>11</sub></td><td>-1.171e+8</td><td></td><td>1.171e+8</td><td></td></tr>
# <tr><td>z<sub>12</sub></td><td>-1.200e+8</td><td></td><td>1.200e+8</td><td></td></tr>
# <tr><td>z<sub>13</sub></td><td>-1.643e+8</td><td></td><td>1.643e+8</td><td></td></tr>
# <tr><td>z<sub>14</sub></td><td>-7.961e+8</td><td></td><td>7.961e+8</td><td></td></tr>
# <tr><td>z<sub>15</sub></td><td>-2.019e+9</td><td></td><td>2.019e+9</td><td></td></tr>
# </table>

# %%
i1.setDataType('pz')
pzResult = i1.execute()
HTML(pz2html(pzResult, label = 'tab_pz'))
# Out:
# <h2><a id="tab_pz"></a>PZ  analysis results</h2>
# <h3>Gain type: gain</h3>
# <p>DC gain = -24.81</p>
# <table><tr><th>pole</th><th>Re [Hz]</th><th>Im [Hz]</th><th>Mag [Hz]</th><th>Q</th></tr>
# <tr><td>p<sub>1</sub></td><td>-4.235e+4</td><td>-2.544e+4</td><td>4.940e+4</td><td>0.5833</td></tr>
# <tr><td>p<sub>2</sub></td><td>-4.235e+4</td><td>2.544e+4</td><td>4.940e+4</td><td>0.5833</td></tr>
# <tr><td>p<sub>3</sub></td><td>-4.997e+5</td><td>-5.114e+5</td><td>7.150e+5</td><td>0.7154</td></tr>
# <tr><td>p<sub>4</sub></td><td>-4.997e+5</td><td>5.114e+5</td><td>7.150e+5</td><td>0.7154</td></tr>
# <tr><td>p<sub>5</sub></td><td>-7.742e+5</td><td></td><td>7.742e+5</td><td></td></tr>
# <tr><td>p<sub>6</sub></td><td>-9.328e+5</td><td>-8.238e+5</td><td>1.245e+6</td><td>0.6671</td></tr>
# <tr><td>p<sub>7</sub></td><td>-9.328e+5</td><td>8.238e+5</td><td>1.245e+6</td><td>0.6671</td></tr>
# <tr><td>p<sub>8</sub></td><td>-7.149e+6</td><td></td><td>7.149e+6</td><td></td></tr>
# <tr><td>p<sub>9</sub></td><td>-1.465e+7</td><td>-1.680e+7</td><td>2.229e+7</td><td>0.7610</td></tr>
# <tr><td>p<sub>10</sub></td><td>-1.465e+7</td><td>1.680e+7</td><td>2.229e+7</td><td>0.7610</td></tr>
# <tr><td>p<sub>11</sub></td><td>-1.053e+8</td><td></td><td>1.053e+8</td><td></td></tr>
# <tr><td>p<sub>12</sub></td><td>-1.168e+8</td><td></td><td>1.168e+8</td><td></td></tr>
# <tr><td>p<sub>13</sub></td><td>-1.115e+9</td><td></td><td>1.115e+9</td><td></td></tr>
# <tr><td>p<sub>14</sub></td><td>-1.660e+9</td><td></td><td>1.660e+9</td><td></td></tr>
# </table>
# <table><tr><th>zero</th><th>Re [Hz]</th><th>Im [Hz]</th><th>Mag [Hz]</th><th>Q</th></tr>
# <tr><td>z<sub>1</sub></td><td>-7.234e+5</td><td></td><td>7.234e+5</td><td></td></tr>
# <tr><td>z<sub>2</sub></td><td>2.833e+6</td><td></td><td>2.833e+6</td><td></td></tr>
# <tr><td>z<sub>3</sub></td><td>1.419e+6</td><td>-2.916e+6</td><td>3.243e+6</td><td>1.143</td></tr>
# <tr><td>z<sub>4</sub></td><td>1.419e+6</td><td>2.916e+6</td><td>3.243e+6</td><td>1.143</td></tr>
# <tr><td>z<sub>5</sub></td><td>-2.171e+6</td><td>-3.373e+6</td><td>4.011e+6</td><td>0.9240</td></tr>
# <tr><td>z<sub>6</sub></td><td>-2.171e+6</td><td>3.373e+6</td><td>4.011e+6</td><td>0.9240</td></tr>
# <tr><td>z<sub>7</sub></td><td>-4.311e+6</td><td></td><td>4.311e+6</td><td></td></tr>
# <tr><td>z<sub>8</sub></td><td>-2.470e+7</td><td></td><td>2.470e+7</td><td></td></tr>
# <tr><td>z<sub>9</sub></td><td>-1.079e+8</td><td></td><td>1.079e+8</td><td></td></tr>
# <tr><td>z<sub>10</sub></td><td>-1.200e+8</td><td></td><td>1.200e+8</td><td></td></tr>
# <tr><td>z<sub>11</sub></td><td>-1.643e+8</td><td></td><td>1.643e+8</td><td></td></tr>
# <tr><td>z<sub>12</sub></td><td>-7.961e+8</td><td></td><td>7.961e+8</td><td></td></tr>
# </table>

# %%
htmlPage('Denominator, nominator, transfer function and step response')

# %%
i1.setDataType('denom')
denom = i1.execute().denom
HTML(eqn2html('D_s', denom))
# Out:
# $$\begin{equation}
# D_{s}=1.761 \cdot 10^{-144} s^{17} + 5.807 \cdot 10^{-134} s^{16} + 6.755 \cdot 10^{-124} s^{15} + 3.288 \cdot 10^{-114} s^{14} + 6.432 \cdot 10^{-105} s^{13} + 6.215 \cdot 10^{-96} s^{12} + 3.222 \cdot 10^{-87} s^{11} + 9.092 \cdot 10^{-79} s^{10} + 1.394 \cdot 10^{-70} s^{9} + 1.236 \cdot 10^{-62} s^{8} + 4.95 \cdot 10^{-55} s^{7} + 8.286 \cdot 10^{-48} s^{6} + 7.695 \cdot 10^{-41} s^{5} + 4.157 \cdot 10^{-34} s^{4} + 1.303 \cdot 10^{-27} s^{3} + 2.086 \cdot 10^{-21} s^{2} + 8.862 \cdot 10^{-16} s + 1.413 \cdot 10^{-10}
# \end{equation}
# $$

# %%
i1.setDataType('numer')
numer = i1.execute().numer
HTML(eqn2html('N_s', numer))
# Out:
# $$\begin{equation}
# N_{s}=3.335 \cdot 10^{-132} s^{15} + 7.185 \cdot 10^{-122} s^{14} + 4.59 \cdot 10^{-112} s^{13} + 1.185 \cdot 10^{-102} s^{12} + 1.555 \cdot 10^{-93} s^{11} + 1.13 \cdot 10^{-84} s^{10} + 4.567 \cdot 10^{-76} s^{9} + 9.498 \cdot 10^{-68} s^{8} + 8.15 \cdot 10^{-60} s^{7} + 1.635 \cdot 10^{-52} s^{6} + 1.67 \cdot 10^{-45} s^{5} + 9.298 \cdot 10^{-39} s^{4} + 1.225 \cdot 10^{-31} s^{3} + 4.565 \cdot 10^{-24} s^{2} - 7.529 \cdot 10^{-16} s - 3.507 \cdot 10^{-9}
# \end{equation}
# $$

# %%
i1.setDataType('laplace')
result = i1.execute()
Fs     = result.laplace
HTML(eqn2html('F_s', Fs))
# Out:
# $$\begin{equation}
# F_{s}=\frac{2.36 \cdot 10^{-122} s^{15} + 5.083 \cdot 10^{-112} s^{14} + 3.247 \cdot 10^{-102} s^{13} + 8.382 \cdot 10^{-93} s^{12} + 1.1 \cdot 10^{-83} s^{11} + 7.996 \cdot 10^{-75} s^{10} + 3.231 \cdot 10^{-66} s^{9} + 6.72 \cdot 10^{-58} s^{8} + 5.766 \cdot 10^{-50} s^{7} + 1.157 \cdot 10^{-42} s^{6} + 1.182 \cdot 10^{-35} s^{5} + 6.579 \cdot 10^{-29} s^{4} + 8.666 \cdot 10^{-22} s^{3} + 3.23 \cdot 10^{-14} s^{2} - 5.327 \cdot 10^{-6} s - 24.81}{1.246 \cdot 10^{-134} s^{17} + 4.109 \cdot 10^{-124} s^{16} + 4.779 \cdot 10^{-114} s^{15} + 2.326 \cdot 10^{-104} s^{14} + 4.551 \cdot 10^{-95} s^{13} + 4.397 \cdot 10^{-86} s^{12} + 2.28 \cdot 10^{-77} s^{11} + 6.433 \cdot 10^{-69} s^{10} + 9.865 \cdot 10^{-61} s^{9} + 8.747 \cdot 10^{-53} s^{8} + 3.502 \cdot 10^{-45} s^{7} + 5.862 \cdot 10^{-38} s^{6} + 5.444 \cdot 10^{-31} s^{5} + 2.942 \cdot 10^{-24} s^{4} + 9.216 \cdot 10^{-18} s^{3} + 1.476 \cdot 10^{-11} s^{2} + 6.27 \cdot 10^{-6} s + 1}
# \end{equation}
# $$

# %%
transferCoeffs      = coeffsTransfer(Fs)
HTML(coeffsTransfer2html(transferCoeffs))
# Out:
# <h3>Gain factor</h3>
# <p>$$-24.81$$</p>
# <h3>Normalized coefficients of the numerator:</h3>
# <table><tr><th class="center">order</th><th class="left">coefficient</th></tr>
# <tr><td class="center">$$0$$</td><td class="left">$$1$$</td></tr>
# <tr><td class="center">$$1$$</td><td class="left">$$2.147 \cdot 10^{-7}$$</td></tr>
# <tr><td class="center">$$2$$</td><td class="left">$$-1.302 \cdot 10^{-15}$$</td></tr>
# <tr><td class="center">$$3$$</td><td class="left">$$-3.492 \cdot 10^{-23}$$</td></tr>
# <tr><td class="center">$$4$$</td><td class="left">$$-2.651 \cdot 10^{-30}$$</td></tr>
# <tr><td class="center">$$5$$</td><td class="left">$$-4.762 \cdot 10^{-37}$$</td></tr>
# <tr><td class="center">$$6$$</td><td class="left">$$-4.661 \cdot 10^{-44}$$</td></tr>
# <tr><td class="center">$$7$$</td><td class="left">$$-2.324 \cdot 10^{-51}$$</td></tr>
# <tr><td class="center">$$8$$</td><td class="left">$$-2.708 \cdot 10^{-59}$$</td></tr>
# <tr><td class="center">$$9$$</td><td class="left">$$-1.302 \cdot 10^{-67}$$</td></tr>
# <tr><td class="center">$$10$$</td><td class="left">$$-3.222 \cdot 10^{-76}$$</td></tr>
# <tr><td class="center">$$11$$</td><td class="left">$$-4.433 \cdot 10^{-85}$$</td></tr>
# <tr><td class="center">$$12$$</td><td class="left">$$-3.378 \cdot 10^{-94}$$</td></tr>
# <tr><td class="center">$$13$$</td><td class="left">$$-1.309 \cdot 10^{-103}$$</td></tr>
# <tr><td class="center">$$14$$</td><td class="left">$$-2.049 \cdot 10^{-113}$$</td></tr>
# <tr><td class="center">$$15$$</td><td class="left">$$-9.51 \cdot 10^{-124}$$</td></tr>
# </table>
# <h3>Normalized coefficients of the denominator:</h3>
# <table><tr><th class="center">order</th><th class="left">coefficient</th></tr>
# <tr><td class="center">$$0$$</td><td class="left">$$1$$</td></tr>
# <tr><td class="center">$$1$$</td><td class="left">$$6.27 \cdot 10^{-6}$$</td></tr>
# <tr><td class="center">$$2$$</td><td class="left">$$1.476 \cdot 10^{-11}$$</td></tr>
# <tr><td class="center">$$3$$</td><td class="left">$$9.216 \cdot 10^{-18}$$</td></tr>
# <tr><td class="center">$$4$$</td><td class="left">$$2.942 \cdot 10^{-24}$$</td></tr>
# <tr><td class="center">$$5$$</td><td class="left">$$5.444 \cdot 10^{-31}$$</td></tr>
# <tr><td class="center">$$6$$</td><td class="left">$$5.862 \cdot 10^{-38}$$</td></tr>
# <tr><td class="center">$$7$$</td><td class="left">$$3.502 \cdot 10^{-45}$$</td></tr>
# <tr><td class="center">$$8$$</td><td class="left">$$8.747 \cdot 10^{-53}$$</td></tr>
# <tr><td class="center">$$9$$</td><td class="left">$$9.865 \cdot 10^{-61}$$</td></tr>
# <tr><td class="center">$$10$$</td><td class="left">$$6.433 \cdot 10^{-69}$$</td></tr>
# <tr><td class="center">$$11$$</td><td class="left">$$2.28 \cdot 10^{-77}$$</td></tr>
# <tr><td class="center">$$12$$</td><td class="left">$$4.397 \cdot 10^{-86}$$</td></tr>
# <tr><td class="center">$$13$$</td><td class="left">$$4.551 \cdot 10^{-95}$$</td></tr>
# <tr><td class="center">$$14$$</td><td class="left">$$2.326 \cdot 10^{-104}$$</td></tr>
# <tr><td class="center">$$15$$</td><td class="left">$$4.779 \cdot 10^{-114}$$</td></tr>
# <tr><td class="center">$$16$$</td><td class="left">$$4.109 \cdot 10^{-124}$$</td></tr>
# <tr><td class="center">$$17$$</td><td class="left">$$1.246 \cdot 10^{-134}$$</td></tr>
# </table>

# %%
# Frequency-domain plots
figdBmag = plotSweep('dBmag', 'dB magnitude', result, 1, 1e3, 100, sweepScale = 'k', funcType = 'dBmag', show = True)
figMag   = plotSweep('mag', 'Magnitude', result, 1, 1e3, 100, sweepScale = 'k', funcType = 'mag', yUnits = '-', show = True)
figPhase = plotSweep('phase', 'Phase', result, 1, 1e3, 100, sweepScale = 'k', funcType = 'phase', show = True)
figDelay = plotSweep('delay', 'Delay', result, 1, 1e3, 100, sweepScale = 'k', yScale = 'u', funcType = 'delay', show = True)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
# Polar plots
figPolar   = plotSweep('polar', 'Polar' , result, 1, 1e3, 100, sweepScale = 'k', axisType = 'polar', funcType = 'mag', show = True)
figdBpolar = plotSweep('dBpolar', 'dB polar' , result, 1, 1e3, 100, funcType = 'dBmag', sweepScale = 'k', axisType = 'polar', show = True)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
i1.setGainType('asymptotic')
asymptotic = i1.execute()
i1.setGainType('loopgain')
loopgain = i1.execute()
# Let us calculate the phase margin
print(phaseMargin(loopgain.laplace))
# Out:
# (61.10393765092847, 79125.51585111124)

# %%
# Let us plot the phase margin as a function of circuit parameters
i1.setStepVar('I_D')
i1.setStepMethod('log')
i1.setStepNum(25)
i1.setStepStart('10p')
i1.setStepStop('1m')
i1.stepOn()
loopgainStepped = i1.execute()
# Trace data for phase margin with C_ph = 2.95pF
# x data is values of step parameter, y data is phase margin
PM2p95 = [i1.stepList, phaseMargin(loopgainStepped.laplace)[0]]
# Trace data for phase margin with C_ph = 1.5pF
i1.defPar('C_ph', '1.5p')
loopgainStepped_1p5 = i1.execute()
# x data is values of step parameter, y data is phase margin
PM1p5 = [i1.stepList, phaseMargin(loopgainStepped_1p5.laplace)[0]]
plotData = {'$C_{ph}=2.95$p': PM2p95, '$C_{ph}=1.5$p': PM1p5}
figPM = plot('PM', 'Phase margin versus $I_D$', 'semilogx', plotData, xName = '$' + sp.latex(i1.stepVar) + '$', xScale = 'u', xUnits = 'A', yName = 'Phase margin', yUnits = 'deg', show = True)

# %%
# Calculate the remaining transfers of the asysmptotic gain model
i1.defPar('C_ph', '2.95p')
i1.stepOff()
i1.setGainType('servo')
servo = i1.execute()
i1.setGainType('direct')
direct = i1.execute()

# %%
# Bode plots of the asymptotic-gain feedback model parameters
figdBmagA = plotSweep('magA', 'dB magnitude feedback model', [result, asymptotic, loopgain, servo, direct], 1, 1e3, 100, funcType = 'dBmag', sweepScale = 'k', show = True)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
i1.setDataType('step')
i1.setGainType('gain')
stepResult = i1.execute()
a_t        = stepResult.stepResp
HTML(eqn2html('a_t', a_t))
# Out:
# $$\begin{equation}
# a_{t}=2.215 \cdot 10^{-7} \left(2.25 \cdot 10^{8} \sin{\left(1.599 \cdot 10^{5} t \right)} + 1.104 \cdot 10^{8} \cos{\left(1.599 \cdot 10^{5} t \right)}\right) e^{- 2.661 \cdot 10^{5} t} + 0.0001124 \left(- 671.2 \sin{\left(3.213 \cdot 10^{6} t \right)} + 3841.0 \cos{\left(3.213 \cdot 10^{6} t \right)}\right) e^{- 3.14 \cdot 10^{6} t} + 0.0002073 \left(- 231.6 \sin{\left(5.176 \cdot 10^{6} t \right)} - 180.4 \cos{\left(5.176 \cdot 10^{6} t \right)}\right) e^{- 5.861 \cdot 10^{6} t} + 0.0006427 \left(- 0.01523 \sin{\left(1.056 \cdot 10^{8} t \right)} - 0.001078 \cos{\left(1.056 \cdot 10^{8} t \right)}\right) e^{- 9.203 \cdot 10^{7} t} - 24.81 - 4.81 \cdot 10^{-17} e^{- 1.269 \cdot 10^{10} t} + 2.499 \cdot 10^{-8} e^{- 1.043 \cdot 10^{10} t} - 1.94 \cdot 10^{-8} e^{- 7.009 \cdot 10^{9} t} - 3.038 \cdot 10^{-11} e^{- 7.359 \cdot 10^{8} t} - 1.636 \cdot 10^{-9} e^{- 7.34 \cdot 10^{8} t} - 3.989 \cdot 10^{-9} e^{- 6.613 \cdot 10^{8} t} + 2.308 \cdot 10^{-11} e^{- 4.755 \cdot 10^{8} t} - 3.333 \cdot 10^{-5} e^{- 4.492 \cdot 10^{7} t} - 0.03434 e^{- 4.865 \cdot 10^{6} t}
# \end{equation}
# $$

# %%
# Time-domain plot
figStep = plotSweep('step', 'step response', stepResult, 0, 50, 100, sweepScale = 'u', yUnits = 'V', show = True)
# Out:
# No handles with labels found to put in legend.

# %%
i1.setGainType('gain')
i1.setDataType('pz')
figPZ = plotPZ('PZ', 'Poles and zeros', pzResult, xmin = -100, xscale = 'M', yscale = 'M', show = True)

# %%
figPZd = plotPZ('PZd', 'Dominant poles and zeros', pzResult, xmin = -100, xmax = 0, ymin = -50, ymax = 50, xscale = 'k', yscale = 'k', show = True)

# %%
# Plots with graphs of asymptotic-gain feedback model transfers
i1.setGainType('gain')
i1.setDataType('laplace')
i1.setStepVar('I_D')
i1.setStepMethod('log')
i1.setStepNum(7)
i1.setStepStart('1p')
i1.setStepStop('1u')
i1.stepOn() 
FsStepped = i1.execute()
figdBs = plotSweep('dBs', 'dB magnitude step I_D', FsStepped, 1, 1e3, 100, funcType = 'dBmag', sweepScale = 'k', show = True)

# %%
# Root-locus plot
i1.setDataType('poles')
i1.setStepNum(200)
polesStepped = i1.execute()
figRL = plotPZ('RL', 'Root Locus I_D', polesStepped, xmin = -180, xmax = 20, ymin = -100, ymax = 100, xscale = 'k', yscale = 'k', show = True)

# %%
# Step responses as a function of I_D
i1.setDataType('step')
i1.setStepNum(7)
a_tStepped = i1.execute()
figStepped = plotSweep('stepped', 'step response versus $I_D$', a_tStepped, 0, 50, 100, sweepScale = 'u', yUnits = 'V', show=True)

# %%
htmlPage('Plots')
fig2html(figdBmag, 600, label = 'figdBmag',  caption='dB magnitude plot of the PIVA transfer.')
fig2html(figMag, 600, label = 'figMag', caption='Magnitude plot of the PIVA transfer.')
fig2html(figPhase, 600, label = 'figPhase', caption='Phase plot of the PIVA transfer.')
fig2html(figDelay, 600, label = 'figDelay', caption='Group delay of the PIVA transfer.')
fig2html(figdBmagA, 600, label = 'figdBmagA', caption='Asymptotic-gain model parameter dB magnitude plots of the PIVA transfer.')
fig2html(figPM, 600, label = 'figPM', caption='Phase margin versus drain current for different values of the phantom zero capacitance.')
fig2html(figPolar, 600, label = 'figPolar', caption ='Polar plot of the PIVA transfer.')
fig2html(figdBpolar, 600, label = 'figdBpolar', caption ='dB polar plot of the PIVA transfer.')
fig2html(figStep, 600, label = 'figStep', caption='Unit step response of the PIVA.')
fig2html(figStepped, 600, label = 'figStepped', caption='Unit step response of the PIVA versus $I_D$.')
fig2html(figPZ, 600, label = 'figPZ', caption='Poles and zeros of the gain of the PIVA.')
fig2html(figPZd,  600, label = 'figPZd', caption='Dominant poles of the gain of the PIVA.')
fig2html(figdBs, 600, label = 'figdBs', caption='dB magnitude plot of the PIVA transfer for different values of the drain current.')
fig2html(figRL, 600, label = 'figRL', caption='Poles of the gain for different values of the drain current.');

# %%
links2html()
t2=time()
print('\nTotal time: %3.1fs'%(t2-t1))
# Out:
# Total time: 62.5s
