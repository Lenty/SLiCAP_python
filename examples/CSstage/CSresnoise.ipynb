# %%
from SLiCAPnotebook import *
# Always run SLiCAP from the project directory, this will use the correct path settings.
t1=time()

# %%
prj = initProject('CS stage noise with resistive source')
fileName = 'CSresNoise.cir'
i1 = instruction()
i1.setCircuit(fileName)
SVG(filename = img2html('CSresNoise.svg', 800))
# Out:
# Warning less than two connections at node: 'out'.
# No errors found for circuit: 'CS stage resistive noise' from file: 'CSresNoise.cir'.

# %%
HTML(netlist2html(fileName))
# Out:
# <h2>Netlist: CSresNoise.cir</h2>
# <pre>"CS stage resistive noise"
# * gnetlist -q -g spice-noqsi -o CSresNoise.net CSresNoise.sch
# * SPICE file generated by spice-noqsi version 20130710
# * Send requests or bug reports to jpd@noqsi.com
# .INCLUDE SLiCAP.lib
# X1 1 0 out NM18_noise ID={ID} W={W} L={L} IG={IG}
# R1 2 1 {R_s}
# V1 2 0 V value=0 dc=0 dcvar=0 noise={4*k*T*R_s}
# .param R_s=600 W=54.6u L=180n ID=6.15m IG=0
# .end
# </pre>

# %%
# Print circuit element data
HTML(elementData2html(i1.circuit))
# Out:
# <table><caption>Table: Element data of expanded netlist 'CS stage resistive noise'</caption>
# <tr><th class="left">RefDes</th><th class="left">Nodes</th><th class="left">Refs</th><th class="left">Model</th><th class="left">Param</th><th class="left">Symbolic</th><th class="left">Numeric</th></tr>
# <tr><td class="left">F1_X1</td><td class = "left">1 0 10_X1 0 </td><td class = "left"></td><td class = "left">F</td>
# <td class="left">value</td><td class="left">$$\frac{s}{2 \pi f_{T X1}}$$</td><td class="left">$$5.675 s \left(\frac{2.009 \cdot 10^{-20} \epsilon_{SiO2}}{\mu_{0}} + 3.276 \cdot 10^{-14}\right) \left(4953.0 \left(\frac{\mu_{0} \left(1 + \frac{3.094 \cdot 10^{6} \mu_{0}}{\epsilon_{SiO2}}\right)}{\epsilon_{SiO2}}\right)^{0.5} + 1 + \frac{9.811 \cdot 10^{7} \mu_{0} \left(1 + \frac{3.094 \cdot 10^{6} \mu_{0}}{\epsilon_{SiO2}}\right)}{\epsilon_{SiO2}}\right)^{0.5}$$</td></tr>
# <tr><td class="left">H1_X1</td><td class = "left">1 out 1_X1 10_X1 </td><td class = "left"></td><td class = "left">H</td>
# <td class="left">value</td><td class="left">$$\frac{1}{g_{m X1}}$$</td><td class="left">$$5.675 \left(4953.0 \left(\frac{\mu_{0} \left(1 + \frac{3.094 \cdot 10^{6} \mu_{0}}{\epsilon_{SiO2}}\right)}{\epsilon_{SiO2}}\right)^{0.5} + 1 + \frac{9.811 \cdot 10^{7} \mu_{0} \left(1 + \frac{3.094 \cdot 10^{6} \mu_{0}}{\epsilon_{SiO2}}\right)}{\epsilon_{SiO2}}\right)^{0.5}$$</td></tr>
# <tr><td class="left">I1_X1</td><td class = "left">0 1_X1 </td><td class = "left"></td><td class = "left">I</td>
# <td class="left">value</td><td class="left">$$0$$</td><td class="left">$$0$$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noise</td><td class="left">$$\frac{4 T k \left(1 + f^{- AF_{X1}} f_{\ell X1}\right)}{R_{N X1}}$$</td><td class="left">$$\frac{3.941 \cdot 10^{-21} \left(0.5 + \frac{6.541 \cdot 10^{7} \mu_{0}}{\epsilon_{SiO2}}\right) \left(\frac{2.075 \cdot 10^{14} \left(\frac{\mu_{0} \left(0.5 + \frac{6.541 \cdot 10^{7} \mu_{0} \left(1 + \frac{3.094 \cdot 10^{6} \mu_{0}}{\epsilon_{SiO2}}\right)}{\epsilon_{SiO2}}\right)}{\epsilon_{SiO2} \left(4953.0 \left(\frac{\mu_{0} \left(1 + \frac{3.094 \cdot 10^{6} \mu_{0}}{\epsilon_{SiO2}}\right)}{\epsilon_{SiO2}}\right)^{0.5} + 1 + \frac{9.811 \cdot 10^{7} \mu_{0} \left(1 + \frac{3.094 \cdot 10^{6} \mu_{0}}{\epsilon_{SiO2}}\right)}{\epsilon_{SiO2}}\right)^{0.5}}\right)^{1.176}}{f^{0.85}} + 1\right)}{\left(1 + \frac{9.811 \cdot 10^{7} \mu_{0}}{\epsilon_{SiO2}}\right) \left(4953.0 \left(\frac{\mu_{0} \left(1 + \frac{3.094 \cdot 10^{6} \mu_{0}}{\epsilon_{SiO2}}\right)}{\epsilon_{SiO2}}\right)^{0.5} + 1 + \frac{9.811 \cdot 10^{7} \mu_{0} \left(1 + \frac{3.094 \cdot 10^{6} \mu_{0}}{\epsilon_{SiO2}}\right)}{\epsilon_{SiO2}}\right)^{0.5}}$$</td></tr>
# <tr><td class="left">I2_X1</td><td class = "left">1 0 </td><td class = "left"></td><td class = "left">I</td>
# <td class="left">value</td><td class="left">$$0$$</td><td class="left">$$0$$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noise</td><td class="left">$$2 IG q$$</td><td class="left">$$0$$</td></tr>
# <tr><td class="left">R1</td><td class = "left">2 1 </td><td class = "left"></td><td class = "left">R</td>
# <td class="left">value</td><td class="left">$$R_{s}$$</td><td class="left">$$600.0$$</td></tr>
# <tr><td class="left">V1</td><td class = "left">2 0 </td><td class = "left"></td><td class = "left">V</td>
# <td class="left">value</td><td class="left">$$0$$</td><td class="left">$$0$$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dc</td><td class="left">$$0$$</td><td class="left">$$0$$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">dcvar</td><td class="left">$$0$$</td><td class="left">$$0$$</td></tr>
# <tr><td></td><td></td><td></td><td></td><td class="left">noise</td><td class="left">$$4 R_{s} T k$$</td><td class="left">$$9.941 \cdot 10^{-18}$$</td></tr>
# </table>

# %%
# Set value of 1/f noise to zero
i1.defPar('KF_X1', 0)

# %%
# Get numeric values of 'I_D', 'IC' and 'IC_CRIT'
i1.simType = 'numeric'
I_D     = i1.getParValue('ID')
IC      = i1.getParValue('IC_X1')
IC_CRIT = i1.getParValue('IC_CRIT_X1')

# %%
# Define the drain current at critical inversion
I_D     = I_D*IC_CRIT/IC
i1.defPar('ID', I_D)

# %%
HTML(params2html(i1.circuit))
# Out:
# <table><caption>Table: Parameter definitions in 'CS stage resistive noise'.</caption>
# <tr><th class="left">Name</th><th class="left">Symbolic</th><th class="left">Numeric</th></tr>
# <tr><td class="left">$$ID$$</td><td class="left">$$\frac{1.988 \cdot 10^{-9} \epsilon_{SiO2}}{\mu_{0}}$$</td><td class="left">$$\frac{1.988 \cdot 10^{-9} \epsilon_{SiO2}}{\mu_{0}}$$</td></tr>
# <tr><td class="left">$$IG$$</td><td class="left">$$0$$</td><td class="left">$$0$$</td></tr>
# <tr><td class="left">$$L$$</td><td class="left">$$1.8 \cdot 10^{-7}$$</td><td class="left">$$1.8 \cdot 10^{-7}$$</td></tr>
# <tr><td class="left">$$R_{s}$$</td><td class="left">$$600$$</td><td class="left">$$600.0$$</td></tr>
# <tr><td class="left">$$T$$</td><td class="left">$$300$$</td><td class="left">$$300.0$$</td></tr>
# <tr><td class="left">$$U_{T}$$</td><td class="left">$$\frac{T k}{q}$$</td><td class="left">$$0.02585$$</td></tr>
# <tr><td class="left">$$W$$</td><td class="left">$$5.46 \cdot 10^{-5}$$</td><td class="left">$$5.46 \cdot 10^{-5}$$</td></tr>
# <tr><td class="left">$$c$$</td><td class="left">$$2.998 \cdot 10^{8}$$</td><td class="left">$$2.998 \cdot 10^{8}$$</td></tr>
# <tr><td class="left">$$\epsilon_{0}$$</td><td class="left">$$\frac{1}{c^{2} \mu_{0}}$$</td><td class="left">$$\frac{1.113 \cdot 10^{-17}}{\mu_{0}}$$</td></tr>
# <tr><td class="left">$$k$$</td><td class="left">$$1.381 \cdot 10^{-23}$$</td><td class="left">$$1.381 \cdot 10^{-23}$$</td></tr>
# <tr><td class="left">$$q$$</td><td class="left">$$1.602 \cdot 10^{-19}$$</td><td class="left">$$1.602 \cdot 10^{-19}$$</td></tr>
# <tr><td class="left">$$AF_{X1}$$</td><td class="left">$$0.85$$</td><td class="left">$$0.85$$</td></tr>
# <tr><td class="left">$$CGBO_{X1}$$</td><td class="left">$$1.0 \cdot 10^{-12}$$</td><td class="left">$$1.0 \cdot 10^{-12}$$</td></tr>
# <tr><td class="left">$$CGSO_{X1}$$</td><td class="left">$$3.0 \cdot 10^{-10}$$</td><td class="left">$$3.0 \cdot 10^{-10}$$</td></tr>
# <tr><td class="left">$$CJB_{0 X1}$$</td><td class="left">$$0.001$$</td><td class="left">$$0.001$$</td></tr>
# <tr><td class="left">$$C_{OX X1}$$</td><td class="left">$$\frac{\epsilon_{0} \epsilon_{SiO2}}{TOX_{X1}}$$</td><td class="left">$$\frac{2.714 \cdot 10^{-9} \epsilon_{SiO2}}{\mu_{0}}$$</td></tr>
# <tr><td class="left">$$E_{CRIT X1}$$</td><td class="left">$$5.6 \cdot 10^{6}$$</td><td class="left">$$5.6 \cdot 10^{6}$$</td></tr>
# <tr><td class="left">$$IC_{CRIT X1}$$</td><td class="left">$$\frac{1}{16 N_{s X1}^{2} U_{T}^{2} \left(\Theta_{X1} + \frac{1}{E_{CRIT X1} L}\right)^{2}}$$</td><td class="left">$$31.71$$</td></tr>
# <tr><td class="left">$$IC_{X1}$$</td><td class="left">$$\frac{ID L}{I_{0 X1} W}$$</td><td class="left">$$31.71$$</td></tr>
# <tr><td class="left">$$I_{0 X1}$$</td><td class="left">$$2 C_{OX X1} N_{s X1} U_{T}^{2} u_{0 X1}$$</td><td class="left">$$\frac{2.067 \cdot 10^{-13} \epsilon_{SiO2}}{\mu_{0}}$$</td></tr>
# <tr><td class="left">$$KF_{X1}$$</td><td class="left">$$0$$</td><td class="left">$$0$$</td></tr>
# <tr><td class="left">$$LDS_{X1}$$</td><td class="left">$$1.8 \cdot 10^{-7}$$</td><td class="left">$$1.8 \cdot 10^{-7}$$</td></tr>
# <tr><td class="left">$$N_{s X1}$$</td><td class="left">$$1.35$$</td><td class="left">$$1.35$$</td></tr>
# <tr><td class="left">$$R_{N X1}$$</td><td class="left">$$\frac{IC_{X1} + 1}{N_{s X1} g_{m X1} \left(\frac{2 IC_{X1}}{3} + \frac{1}{2}\right)}$$</td><td class="left">$$\frac{1.626 \cdot 10^{8} \mu_{0}}{\epsilon_{SiO2}}$$</td></tr>
# <tr><td class="left">$$TOX_{X1}$$</td><td class="left">$$4.1 \cdot 10^{-9}$$</td><td class="left">$$4.1 \cdot 10^{-9}$$</td></tr>
# <tr><td class="left">$$\Theta_{X1}$$</td><td class="left">$$0.28$$</td><td class="left">$$0.28$$</td></tr>
# <tr><td class="left">$$c_{db X1}$$</td><td class="left">$$CJB_{0 X1} LDS_{X1} W$$</td><td class="left">$$9.828 \cdot 10^{-15}$$</td></tr>
# <tr><td class="left">$$c_{dg X1}$$</td><td class="left">$$CGSO_{X1} W$$</td><td class="left">$$1.638 \cdot 10^{-14}$$</td></tr>
# <tr><td class="left">$$c_{gb X1}$$</td><td class="left">$$2 CGBO_{X1} L + \frac{C_{OX X1} L W \left(N_{s X1} - 1\right)}{3 N_{s X1}}$$</td><td class="left">$$\frac{2.305 \cdot 10^{-21} \epsilon_{SiO2}}{\mu_{0}} + 3.6 \cdot 10^{-19}$$</td></tr>
# <tr><td class="left">$$c_{gs X1}$$</td><td class="left">$$CGSO_{X1} W + \frac{2 C_{OX X1} L W}{3}$$</td><td class="left">$$\frac{1.778 \cdot 10^{-20} \epsilon_{SiO2}}{\mu_{0}} + 1.638 \cdot 10^{-14}$$</td></tr>
# <tr><td class="left">$$c_{iss X1}$$</td><td class="left">$$c_{dg X1} + c_{gb X1} + c_{gs X1}$$</td><td class="left">$$\frac{2.009 \cdot 10^{-20} \epsilon_{SiO2}}{\mu_{0}} + 3.276 \cdot 10^{-14}$$</td></tr>
# <tr><td class="left">$$f_{T X1}$$</td><td class="left">$$\frac{g_{m X1}}{2 \pi c_{iss X1}}$$</td><td class="left">$$\frac{1.096 \cdot 10^{-9} \epsilon_{SiO2}}{\mu_{0} \left(\frac{2.009 \cdot 10^{-20} \epsilon_{SiO2}}{\mu_{0}} + 3.276 \cdot 10^{-14}\right)}$$</td></tr>
# <tr><td class="left">$$f_{\ell X1}$$</td><td class="left">$$\left(\frac{KF_{X1} g_{m X1} \left(\frac{2 IC_{X1} \left(1 + \frac{IC_{X1}}{IC_{CRIT X1}}\right)}{3} + \frac{1}{2}\right)}{4 C_{OX X1} L N_{s X1} T W k}\right)^{\frac{1}{AF_{X1}}}$$</td><td class="left">$$0$$</td></tr>
# <tr><td class="left">$$g_{m X1}$$</td><td class="left">$$\frac{ID}{N_{s X1} U_{T} \sqrt{IC_{X1} \left(1 + \frac{IC_{X1}}{IC_{CRIT X1}}\right) + 0.5 \sqrt{IC_{X1} \left(1 + \frac{IC_{X1}}{IC_{CRIT X1}}\right)} + 1}}$$</td><td class="left">$$\frac{6.887 \cdot 10^{-9} \epsilon_{SiO2}}{\mu_{0}}$$</td></tr>
# <tr><td class="left">$$u_{0 X1}$$</td><td class="left">$$0.0422$$</td><td class="left">$$0.0422$$</td></tr>
# </table>
# <table><caption>Table: Parameters without definition in 'CS stage resistive noise.</caption>
#
# <tr><th class="left">Name</th></tr>
# <tr><td class="left">$$\epsilon_{SiO2}$$</td></tr>
# </table>

# %%
R_N   = i1.getParValue('R_N_X1')
R_s   = i1.getParValue('R_s')
f_T   = i1.getParValue('f_T_X1')
g_m   = i1.getParValue('g_m_X1')
Width = i1.getParValue('W')

# %%
htmlPage('Noise analysis')

# %%
i1.setSource('V1')
i1.setDetector('V_out')
i1.setGainType('vi')
i1.setDataType('noise')
i1.setSimType('numeric')
noise_result = i1.execute()
plotSweep('Inoise', 'Source-referred noise spectrum', noise_result, 1e8, 1e11, 100, funcType = 'inoise', show=True)
# Out:
# Error in plot data of Inoise.svg.
# No handles with labels found to put in legend.

# %%
# Calculate the noise figure at critical inversion and the given width
tot_inoise     = rmsNoise(noise_result, 'inoise', 1e9, 5e9)
tot_inoise_src = rmsNoise(noise_result, 'inoise', 1e9, 5e9, source = noise_result.source)
HTML(noise2html(noise_result))
# Out:
# <h2>Numeric noise analysis results</h2>
# <h3>Detector-referred noise spectrum</h3>
# $$S_{out}=9.941 \cdot 10^{-18} + \frac{1.019 \cdot 10^{-28} \left(1.209 \cdot 10^{-16} \epsilon_{SiO2}^{2} f^{2} + 3.944 \cdot 10^{-10} \epsilon_{SiO2} f^{2} \mu_{0} + 0.0003216 f^{2} \mu_{0}^{2} + 2.109 \cdot 10^{16} \mu_{0}^{2}\right)}{\epsilon_{SiO2} \mu_{0}}\, \mathrm{\left[\frac{V^2}{Hz}\right]}$$
# <h3>Source-referred noise spectrum</h3>
# $$S_{in}=\frac{0.1209 \left(1.019 \cdot 10^{-43} \epsilon_{SiO2}^{2} f^{2} + 3.324 \cdot 10^{-37} \epsilon_{SiO2} f^{2} \mu_{0} + 8.222 \cdot 10^{-17} \epsilon_{SiO2} \mu_{0} + 2.711 \cdot 10^{-31} f^{2} \mu_{0}^{2} + 1.777 \cdot 10^{-11} \mu_{0}^{2}\right)}{\epsilon_{SiO2} \mu_{0}}\, \mathrm{\left[\frac{V^2}{Hz}\right]}$$
# <h3>Contributions of individual noise sources</h3><table>
# <th colspan = "3" class="center">Noise source: I1_X1</th><tr><td class="title">Spectral density:</td><td>$$\frac{1.019 \cdot 10^{-28} \epsilon_{SiO2}}{\mu_{0}}$$</td><td class="units">$$\,\mathrm{\left[\frac{A^2}{Hz}\right]}$$</td></tr>
# <tr><td class="title">Detector-referred:</td><td>$$\frac{1.019 \cdot 10^{-28} \left(1.209 \cdot 10^{-16} \epsilon_{SiO2}^{2} f^{2} + 3.944 \cdot 10^{-10} \epsilon_{SiO2} f^{2} \mu_{0} + 0.0003216 f^{2} \mu_{0}^{2} + 2.109 \cdot 10^{16} \mu_{0}^{2}\right)}{\epsilon_{SiO2} \mu_{0}}$$</td><td class="units">$$\,\mathrm{\left[\frac{V^2}{Hz}\right]}$$</td></tr>
# <tr><td class="title">Source-referred:</td><td>$$\frac{0.1209 \left(1.019 \cdot 10^{-43} \epsilon_{SiO2}^{2} f^{2} + 3.324 \cdot 10^{-37} \epsilon_{SiO2} f^{2} \mu_{0} + 2.711 \cdot 10^{-31} f^{2} \mu_{0}^{2} + 1.777 \cdot 10^{-11} \mu_{0}^{2}\right)}{\epsilon_{SiO2} \mu_{0}}$$</td><td class="units">$$\,\mathrm{\left[\frac{V^2}{Hz}\right]}$$</td></tr>
# <th colspan = "3" class="center">Noise source: I2_X1</th><tr><td class="title">Spectral density:</td><td>$$0$$</td><td class="units">$$\,\mathrm{\left[\frac{A^2}{Hz}\right]}$$</td></tr>
# <tr><td class="title">Detector-referred:</td><td>$$0$$</td><td class="units">$$\,\mathrm{\left[\frac{V^2}{Hz}\right]}$$</td></tr>
# <tr><td class="title">Source-referred:</td><td>$$0$$</td><td class="units">$$\,\mathrm{\left[\frac{V^2}{Hz}\right]}$$</td></tr>
# <th colspan = "3" class="center">Noise source: V1</th><tr><td class="title">Spectral density:</td><td>$$9.941 \cdot 10^{-18}$$</td><td class="units">$$\,\mathrm{\left[\frac{V^2}{Hz}\right]}$$</td></tr>
# <tr><td class="title">Detector-referred:</td><td>$$9.941 \cdot 10^{-18}$$</td><td class="units">$$\,\mathrm{\left[\frac{V^2}{Hz}\right]}$$</td></tr>
# <tr><td class="title">Source-referred:</td><td>$$9.941 \cdot 10^{-18}$$</td><td class="units">$$\,\mathrm{\left[\frac{V^2}{Hz}\right]}$$</td></tr>
# </table>

# %%
NF           = 20*sp.log(tot_inoise/tot_inoise_src)/sp.log(10)
print("The noise figure equals: %s [dB]."%(sp.N(NF, ini.disp)))
# Out:
# The noise figure equals: 8.686*log(5014.89899440998*((5.0922269819093e-16*epsilon_SiO2**2 + 4.14238000777714e-8*epsilon_SiO2*mu_0 + 0.0099494747714676*mu_0**2)/(epsilon_SiO2*mu_0))**0.5) [dB].

# %%
# We will now calculate the width W at which we will have the best noise performance.
# Define the variable 'W' in the notebook environment
W               = sp.Symbol('W', positive = True)
i1.delPar('W')        # delete the numeric definition of the width
# We will keep the inversion coefficient at critical inversion, hence we scale the
# current with the width.
# Please know that not scaling the current results in expressions that cannot be integrated symbolically.
# We will then need numeric methods for determination of the optimum width.
i1.defPar('ID', I_D*W/Width)
noise_w = i1.execute() # calculate the noise spectra as a function of W and f
# Calculate the noise figure as a function of W over a frequency range from 'fmin' to 'fmax':
f_min = sp.Symbol('f_min', positive = True)
f_max = sp.Symbol('f_max', positive = True)
rms_noise_w        = rmsNoise(noise_w, 'inoise', f_min, f_max)
rms_noise_w_source = rmsNoise(noise_w, 'inoise', f_min, f_max, noise_w.source)
# We will now calculate the noise figure as a function of 'W', 'f_min' and 'f_max':
# We will use the variance instead of the RMS value:
NF_W            = assumePosParams((rms_noise_w/rms_noise_w_source)**2)
# We will now calculate the optimum width as a function of 'fmin' and 'fmax':
W_opt           = sp.solve(sp.diff(NF_W, W), W)
# The sympy solve function returns a list with solutions, we will print the ones
# that are positive over the frequency range of interest.
for w in W_opt:
    w = sp.N(w.subs([(f_min, 1e9), (f_max, 5e9)]), ini.disp)
    if w > 0:
        print(w)
# Out:
# 2.685e+52*mu_0*(1.433e+100*epsilon_SiO2**2 + 4.675e+106*epsilon_SiO2*mu_0 + 3.812e+112*mu_0**2)**(-0.5)

# %%
# The noise figure over the frequency range of interest, as a function of the width is:
HTML('$' + sp.latex(roundN(sp.expand(NF_W.subs([(f_min, 1e9), (f_max, 5e9)])))) + '$')
# Out:
# $\frac{2.515 \cdot 10^{7} \left(9.326 \cdot 10^{-12} W^{2} \epsilon_{SiO2}^{2} + 3.042 \cdot 10^{-5} W^{2} \epsilon_{SiO2} \mu_{0} + 24.81 W^{2} \mu_{0}^{2} + 3.976 \cdot 10^{-8} W \epsilon_{SiO2} \mu_{0} + 2.977 \cdot 10^{-8} W \mu_{0}^{2} + 4.693 \cdot 10^{-7} \mu_{0}^{2}\right)}{W \epsilon_{SiO2} \mu_{0}}$

# %%
# Create a plot of the noise figure versus the with for different values of f_max and f_min = 1G
# Define the plot parameters, 'fw', 'W' and 'fmax'
i1.defPar('W', w)
i1.defPar('f_max', '10G')
i1.defPar('NF', 10*sp.log(NF_W.subs([(f_min, 2e8)]))/sp.log(10))
# Define the step parameters
i1.setStepVar('f_max')
i1.setStepStart('2G')
i1.setStepStop('10G')
i1.setStepMethod('lin')
i1.setSimType('numeric')
i1.setStepNum(5)
i1.stepOn()
result = i1.execute()
# Plot the function
fig_NF_W = plotSweep('NF_W', 'Noise Figure versus width, $f_{min}$ = 200MHz', result, 10, 200, 50, sweepVar = 'W', sweepScale = 'u', funcType = 'param', xUnits = 'm', yVar = 'NF', yUnits = 'dB', show = True)
t2 = time()
print(t2-t1, 's')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-1dc9ff11bec5> in <module>
#      14 result = i1.execute()
#      15 # Plot the function
# ---> 16 fig_NF_W = plotSweep('NF_W', 'Noise Figure versus width, $f_{min}$ = 200MHz', result, 10, 200, 50, sweepVar = 'W', sweepScale = 'u', funcType = 'param', xUnits = 'm', yVar = 'NF', yUnits = 'dB', show = True)
#      17 t2 = time()
#      18 print(t2-t1, 's')
#
# ~/Documents/SED/SLiCAP_python/SLiCAPplots.py in plotSweep(fileName, title, results, sweepStart, sweepStop, sweepNum, sweepVar, sweepScale, xVar, xScale, xUnits, axisType, funcType, yVar, yScale, yUnits, noiseSources, show)
#     594     # Other simulation results are simply ignored (plots would become messy).
#     595     if funcType == 'param':
# --> 596         xData, yData = stepParams(result, xVar, yVar, sweepVar, x)
#     597         if type(xData) == dict:
#     598             keys = sorted(xData.keys())
#
# ~/Documents/SED/SLiCAP_python/SLiCAPplots.py in stepParams(results, xVar, yVar, sVar, sweepList)
#    1210                 y = f.subs(results.stepVar, parValue)
#    1211                 yfunc = sp.lambdify(sp.Symbol(sVar), y)
# -> 1212                 yValues[parValue] = yfunc(sweepList)
#    1213                 if xVar != sVar:
#    1214                     x = g.subs(results.stepVar, parValue)
#
# <lambdifygenerated-2> in _lambdifygenerated(W)
#       1 def _lambdifygenerated(W):
# ----> 2     return (10*log(55887137.6091871*W**(-1.0)*epsilon_SiO2**(-1.0)*mu_0**(-1.0)*(6.01103007790072e-13*W**2*epsilon_SiO2**2 + 1.78932048192e-8*W*epsilon_SiO2*mu_0 + 4.83131694385657e-130*epsilon_SiO2*mu_0*(4.05856550165317e+123*W**2 + 2.4351393009919e+114*W) - 6.0451913711919e-158*mu_0**2*(2.64784002392045e+154*W**2 + 3.17740802870454e+145*W + 3.88139880380762e+149) + 6.0451913711919e-158*mu_0**2*(2.64784002392046e+157*W**2 + 3.17740802870454e+148*W + 3.88139880381705e+150))**1.0)/log(10))
#
# <__array_function__ internals> in log(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/scimath.py in log(x)
#     271
#     272     """
# --> 273     x = _fix_real_lt_zero(x)
#     274     return nx.log(x)
#     275
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/scimath.py in _fix_real_lt_zero(x)
#     120     """
#     121     x = asarray(x)
# --> 122     if any(isreal(x) & (x < 0)):
#     123         x = _tocomplex(x)
#     124     return x
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/relational.py in __nonzero__(self)
#     302
#     303     def __nonzero__(self):
# --> 304         raise TypeError("cannot determine truth value of Relational")
#     305
#     306     __bool__ = __nonzero__
#
# TypeError: cannot determine truth value of Relational
