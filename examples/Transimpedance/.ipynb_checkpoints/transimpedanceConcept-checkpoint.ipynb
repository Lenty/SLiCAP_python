# %%
from SLiCAPnotebook import *
prj = initProject('Transimpedance')
instr = instruction()
instr.setCircuit('transimpedanceConcept.cir')
htmlPage('Concept design')
HTML(head2html('Amplifier two-port concept'))
# Out:
# No errors found for circuit: 'Concept design' from file: 'transimpedanceConcept.cir'.
# <h2>Amplifier two-port concept</h2>

# %%
HTML(text2html('Below you find the circuit diagram of the application in which the amplifier is modeled as a two-port with its transmission-1 parameters A, B, C, D.'))
# Out:
# <p>Below you find the circuit diagram of the application in which the amplifier is modeled as a two-port with transmission-1 parameters A, B, C, D.</p>

# %%
HTML(img2html('transimpedanceConcept.svg', 700))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <svg
#    xmlns:dc="http://purl.org/dc/elements/1.1/"
#    xmlns:cc="http://creativecommons.org/ns#"
#    xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#    xmlns:svg="http://www.w3.org/2000/svg"
#    xmlns="http://www.w3.org/2000/svg"
#    viewBox="0 0 742.6391 277.99395"
#    height="277.99396"
#    width="742.6391"
#    xml:space="preserve"
#    id="svg2"
#    version="1.1"><metadata
#      id="metadata8"><rdf:RDF><cc:Work
#          rdf:about=""><dc:format>image/svg+xml</dc:format><dc:type
#            rdf:resource="http://purl.org/dc/dcmitype/StillImage" /><dc:title></dc:title></cc:Work></rdf:RDF></metadata><defs
#      id="defs6" /><g
#      transform="matrix(1.3333333,0,0,-1.3333333,-20.865643,708.88993)"
#      id="g10"><g
#        transform="scale(0.24)"
#        id="g12"><path
#          id="path14"
# ...

# %%
HTML(head2html('Source-to-load transfer'))
# Out:
# <h2>Source-to-load transfer</h2>

# %%
instr.setSimType('numeric')
instr.setGainType('gain')
instr.setDataType('laplace')
instr.setSource('I1')
instr.setDetector('V_out')
s_l_transfer = instr.execute().laplace
HTML('The source-to-load transfer can be written as:')
